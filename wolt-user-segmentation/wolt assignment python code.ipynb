# %%
import numpy as np
import pandas as pd

df = pd.read_csv('dataset_for_analyst_assignment.csv')

df.head(2)
# Out:
#          REGISTRATION_DATE REGISTRATION_COUNTRY  PURCHASE_COUNT  \
# 0  2019-09-01 00:00:00.000                  DNK               0
# 1  2019-09-01 00:00:00.000                  FIN               1
#
#    PURCHASE_COUNT_DELIVERY  PURCHASE_COUNT_TAKEAWAY       FIRST_PURCHASE_DAY  \
# 0                      NaN                      NaN                      NaN
# 1                      1.0                      0.0  2020-09-02 00:00:00.000
#
#          LAST_PURCHASE_DAY  USER_ID  BREAKFAST_PURCHASES  LUNCH_PURCHASES  \
# 0                      NaN        1                  NaN              NaN
# 1  2020-09-02 00:00:00.000        2                  0.0              1.0
#
#    ...  WEB_PURCHASES  ANDROID_PURCHASES  PREFERRED_RESTAURANT_TYPES  \
# 0  ...            NaN                NaN                         NaN
# 1  ...            0.0                1.0                         NaN
#
#    USER_HAS_VALID_PAYMENT_METHOD  MOST_COMMON_HOUR_OF_THE_DAY_TO_PURCHASE  \
# ...

# %%
for col in df.columns:
    dtype = df[col].dtype
    value_in_first_row = df.iloc[0][col]
    print(f"{col} - {dtype}, {value_in_first_row}")
# Out:
# REGISTRATION_DATE - object, 2019-09-01 00:00:00.000
# REGISTRATION_COUNTRY - object, DNK
# PURCHASE_COUNT - int64, 0
# PURCHASE_COUNT_DELIVERY - float64, nan
# PURCHASE_COUNT_TAKEAWAY - float64, nan
# FIRST_PURCHASE_DAY - object, nan
# LAST_PURCHASE_DAY - object, nan
# USER_ID - int64, 1
# BREAKFAST_PURCHASES - float64, nan
# LUNCH_PURCHASES - float64, nan
# EVENING_PURCHASES - float64, nan
# DINNER_PURCHASES - float64, nan
# LATE_NIGHT_PURCHASES - float64, nan
# TOTAL_PURCHASES_EUR - float64, nan
# DISTINCT_PURCHASE_VENUE_COUNT - float64, nan
# MIN_PURCHASE_VALUE_EUR - float64, nan
# MAX_PURCHASE_VALUE_EUR - float64, nan
# AVG_PURCHASE_VALUE_EUR - float64, nan
# PREFERRED_DEVICE - object, ios
# IOS_PURCHASES - float64, nan
# WEB_PURCHASES - float64, nan
# ANDROID_PURCHASES - float64, nan
# PREFERRED_RESTAURANT_TYPES - object, nan
# USER_HAS_VALID_PAYMENT_METHOD - bool, False
# MOST_COMMON_HOUR_OF_THE_DAY_TO_PURCHASE - float64, nan
# MOST_COMMON_WEEKDAY_TO_PURCHASE - float64, nan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21983 entries, 0 to 21982
# Data columns (total 30 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   REGISTRATION_DATE                        21983 non-null  object
#  1   REGISTRATION_COUNTRY                     21983 non-null  object
#  2   PURCHASE_COUNT                           21983 non-null  int64
#  3   PURCHASE_COUNT_DELIVERY                  12028 non-null  float64
#  4   PURCHASE_COUNT_TAKEAWAY                  12028 non-null  float64
#  5   FIRST_PURCHASE_DAY                       11964 non-null  object
#  6   LAST_PURCHASE_DAY                        12027 non-null  object
#  7   USER_ID                                  21983 non-null  int64
#  8   BREAKFAST_PURCHASES                      12028 non-null  float64
#  9   LUNCH_PURCHASES                          12028 non-null  float64
# ...
